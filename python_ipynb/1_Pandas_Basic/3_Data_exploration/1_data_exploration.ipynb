# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine  #requied libraries for mysql connection
from dotenv import load_dotenv
import os
load_dotenv() 
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")         # e.g., 'localhost' or '127.0.0.1'
port = os.getenv("DB_PORT")         # default MySQL port
database = os.getenv("DB_NAME")
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")
query = "select * from pd_users;"
print(query)
df = pd.read_sql(query,engine)
df

# %%
df.head(2) #display first two rows by default it displays first 5 rows

# %%
df.tail(2) # display last two rows and by default it shows only last 5 rows

# %%
df.sample(2)    #display random two rows and by default it display 5 rows

# %%
df.shape       #it show stucture of dataset

# %%
# shows a quick summary of the DataFrame — columns, data types, and missing values.
df.info()

# %%
df.describe()       #gives basic statistics for numeric columns (count, mean, min, max, etc.).

# %%
df.columns      
# shows the names of all columns in the DataFrame.

# %%
df.index
# shows the row labels (index) of the DataFrame.

# %%
df.dtypes
#shows the data type of each column in the DataFrame.
