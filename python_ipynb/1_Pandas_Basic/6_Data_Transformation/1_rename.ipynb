# %%
import pandas as pd
df = pd.read_csv("employee.csv")
df.head(2)

# %% [markdown]
# ##### rename function for rename multiple columns
# ##### method 1

# %%
df.rename(columns={'ID':'id','FirstName':'firstname'}).columns
# Changes the column name(s) in your table.

# %% [markdown]
# ##### ##### rename function for change case  columns
# ##### method 2

# %%
df.columns.str.lower()

# %%
df.columns = df.columns.str.lower()

# %%
df.columns

# %% [markdown]
# ##### method 3

# %%
df.rename(columns=str.upper).columns
# Convert all column names to lowercase
