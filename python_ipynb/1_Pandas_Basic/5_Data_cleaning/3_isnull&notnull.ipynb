# %%
import pandas as pd
df = pd.read_csv("employee.csv")
df.head(2)

# %% [markdown]
# ##### isnull,notnull,fillna,replace,df.duplicated

# %%
df.shape

# %%
df.isnull().sum()
# checks for missing values in the DataFrame and returns a DataFrame of True/False.

# %%
df.notnull().sum()
#is the opposite of isnull() — it checks for non-missing values.
