# %%
import pandas as pd
df = pd.read_csv("employee.csv")
df.head(2)

# %%
df.isna().sum()

# %% [markdown]
# ##### df.dropna(axis=0, how='any', subset=None, inplace=False)

# %%
df.shape

# %%
df.dropna().shape
#removes rows with missing (NaN) values from the DataFrame.

# %%
df.dropna(axis=1).shape
#removes column with missing (NaN) values from the DataFrame.
