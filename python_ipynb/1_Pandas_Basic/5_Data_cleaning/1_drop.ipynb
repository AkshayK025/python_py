# %%
import pandas as pd
df = pd.read_csv("employee.csv")
df.head(2)

# %% [markdown]
# #### drop columns
# ##### df.drop(labels, axis=0, inplace=False)

# %%
df.columns

# %%
df.drop('LastName',axis=1).columns
#removes rows or columns from the DataFrame.

# %%
df.drop(['ID','FirstName'],axis=1).columns
#removes multiple columns from the df

# %%
df.drop(df.columns[0:3],axis=1).columns
#drop columns by position (using range)

# %% [markdown]
# #### drop rows
# ##### df.drop(labels, axis=0, inplace=False)

# %%
df.drop(1).shape
# drop index 1 row

# %%
df.drop([0,2,5]).shape
# drop multiple rows by giving index

# %%
df.drop(range(0,3)).shape
#drop rows 0,1,2 and by default axis = 0 for rows deletion
