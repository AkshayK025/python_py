# %%
import pandas as pd
df = pd.read_csv("employee.csv")
df.head(2)

# %%
df

# %%
df.iloc[[0,3]]

# %%
df.at[3,'ID'] = 1

# %%
df.iloc[[0,3]]

# %%
df.duplicated().value_counts()

# %%
df.drop_duplicates().duplicated().value_counts()
