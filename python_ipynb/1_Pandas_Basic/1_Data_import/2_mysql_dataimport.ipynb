# %% [markdown]
# ##### required libraries

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine  #requied libraries for mysql connection

# %% [markdown]
# ##### for data sercurity

# %%
from dotenv import load_dotenv
import os
load_dotenv() 
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")         # e.g., 'localhost' or '127.0.0.1'
port = os.getenv("DB_PORT")         # default MySQL port
database = os.getenv("DB_NAME")

# %%
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# %%
query = "select * from pd_users;"
print(query)
# Out:
# select * from pd_users;

# %%
df = pd.read_sql(query,engine)

# %%
df
# Out:
#    user_id     full_name                   email   location  \
# 0        1  Aarav Sharma  aarav.sharma@gmail.com      Delhi
# 1        2    Neha Verma    neha.verma@gmail.com     Mumbai
# 2        3   Rohan Mehta   rohan.mehta@gmail.com  Ahmedabad
# 3        4   Priya Singh   priya.singh@gmail.com  Bangalore
# 4        5   Kunal Patel   kunal.patel@gmail.com      Surat
#
#             join_date  time_credits
# 0 2026-01-24 09:46:25             5
# 1 2026-01-24 09:46:25             8
# 2 2026-01-24 09:46:25             3
# 3 2026-01-24 09:46:25            10
# 4 2026-01-24 09:46:25             6
